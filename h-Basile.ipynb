# %%
import common
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = common.load_data()
#df = pd.read_excel("DataForTable2.1WHR2023.xls")#,index_col = [0,1])

common.normalize_avec_zero(df,"Life Ladder")
df.head(1)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     0.467148            7.350416        0.450662
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                      0.718114    0.167652
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                   0.881686         0.414297         0.258195

# %%
#df["Life Ladder"].loc[("Afghanistan",2008)]
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1958.000000  1958.000000         1958.000000     1958.000000
# mean   2014.308478     0.684824            9.344040        0.808119
# std       4.640344     0.143149            1.157988        0.123489
# min    2005.000000     0.273346            5.526723        0.290184
# 25%    2011.000000     0.578195            8.442262        0.739302
# 50%    2014.000000     0.676313            9.493933        0.834138
# 75%    2018.000000     0.787200           10.303009        0.906110
# max    2022.000000     1.000000           11.663788        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1958.000000                   1958.000000
# mean                          63.156228                      0.745463
# std                            7.068698                      0.140515
# min                            6.720000                      0.257534
# ...

# %%
mask = (df["Country name"] == "Zimbabwe")
plt.plot(df["year"][mask],df["Healthy life expectancy at birth"][mask])

# %%
def histogram(serie:pd.Series,nbins:int):
    plt.hist(serie,bins=nbins)
    plt.show()


def correlation_plot_advanced(xdata,ydata,xlabel,ylabel,plot_kwargs):
    plt.plot(xdata,ydata,**plot_kwargs)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

def correlation_plot(xdata,ydata):
    plt.scatter(xdata,ydata)
    plt.show()

# %%
mask = (df["year"] == 2018)
correlation_plot(df[mask]["Healthy life expectancy at birth"],df[mask]["Generosity"])

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
import seaborn as sns
# Calculer la matrice de corrélation
correlation_matrix = df[mask][['Life Ladder', 'Log GDP per capita',
       'Social support', 'Healthy life expectancy at birth',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption', 'Positive affect', 'Negative affect']].corr()

# Configurer la taille de la figure
plt.figure(figsize=(10, 8))

# Créer un heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)

# Ajouter un titre
plt.title("Matrice de Corrélation")

# Afficher le graphique
plt.show()
